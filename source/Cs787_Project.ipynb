# %%
# !git clone https://github.com/mayug/VDT-Adapter.git
# Out:
# Cloning into 'VDT-Adapter'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 185 (delta 43), reused 37 (delta 37), pack-reused 129 (from 1)
# Receiving objects: 100% (185/185), 2.56 MiB | 29.49 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# !pip install openai-clip
# !pip install git+https://github.com/KaiyangZhou/Dassl.pytorch.git
# !pip install lpips
# Out:
# ...
#   Cloning https://github.com/KaiyangZhou/Dassl.pytorch.git to /tmp/pip-req-build-an9dsmub
#   Running command git clone --filter=blob:none --quiet https://github.com/KaiyangZhou/Dassl.pytorch.git /tmp/pip-req-build-an9dsmub
#   Resolved https://github.com/KaiyangZhou/Dassl.pytorch.git to commit c61a1b570ac6333bd50fb5ae06aea59002fb20bb
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached lpips-0.1.4-py3-none-any.whl (53 kB)
# ...

# %%
cd VDT-Adapter
# Out:
# /content/VDT-Adapter

# %%
# !mkdir -p /FEAT/data/oxford_pets
# !wget https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz -P /FEAT/data/oxford_pets/
# !wget https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz -P /FEAT/data/oxford_pets/
# !tar -xzf /FEAT/data/oxford_pets/images.tar.gz -C /FEAT/data/oxford_pets/
# !tar -xzf /FEAT/data/oxford_pets/annotations.tar.gz -C /FEAT/data/oxford_pets/
# Out:
# --2025-09-22 13:03:25--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/pets/images.tar.gz [following]
# --2025-09-22 13:03:26--  https://thor.robots.ox.ac.uk/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘/FEAT/data/oxford_pets/images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  25.3MB/s    in 29s
#
# 2025-09-22 13:03:55 (26.2 MB/s) - ‘/FEAT/data/oxford_pets/images.tar.gz’ saved [791918971/791918971]
#
# ...

# %%
# !bash scripts/clip/main_gpt.sh oxford_pets vit_b16_c16_ep10_batch1 all zs_gpt_v
# Out:
# 2025-09-22 13:04:15.351559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758546255.371642    3093 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758546255.377895    3093 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758546255.393268    3093 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !mkdir -p /FEAT/data/fgvc_aircraft
# !wget https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz -P /FEAT/data/fgvc_aircraft/
# !wget https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b-annotations.tar.gz -P /FEAT/data/fgvc_aircraft/
# !tar -xzf /FEAT/data/fgvc_aircraft/fgvc-aircraft-2013b.tar.gz -C /FEAT/data/fgvc_aircraft/
# !tar -xzf /FEAT/data/fgvc_aircraft/fgvc-aircraft-2013b-annotations.tar.gz -C /FEAT/data/fgvc_aircraft/
# Out:
# --2025-11-14 13:17:47--  https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2753340328 (2.6G) [application/x-gzip]
# Saving to: ‘/FEAT/data/fgvc_aircraft/fgvc-aircraft-2013b.tar.gz.1’
#
# fgvc-aircraft-2013b 100%[===================>]   2.56G  17.2MB/s    in 2m 34s
#
# 2025-11-14 13:20:22 (17.1 MB/s) - ‘/FEAT/data/fgvc_aircraft/fgvc-aircraft-2013b.tar.gz.1’ saved [2753340328/2753340328]
#
# --2025-11-14 13:20:22--  https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b-annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !bash scripts/clip/main_gpt.sh fgvc_aircraft vit_b16_c16_ep10_batch1 all zs_gpt_v
# Out:
# 2025-11-14 13:28:16.283985: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763126896.303635   14869 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763126896.309662   14869 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763126896.325467   14869 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
